# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use ("fivethirtyeight")

# %%
data=pd.read_csv('../input/land-ocean-temperature-index/Land Ocean Temp Index.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#      Year  No_Smoothing  Lowess(5)
# 52   1932         -0.16      -0.18
# 47   1927         -0.22      -0.21
# 109  1989          0.27       0.33
# 25   1905         -0.26      -0.34
# 51   1931         -0.10      -0.19
# 60   1940          0.13       0.06
# 1    1881         -0.08      -0.12
# 81   1961          0.06       0.02
# 131  2011          0.61       0.66
# 30   1910         -0.43      -0.41

# %%
year= df ['Year']
temp_change_rate= df ['No_Smoothing']

# %%
x=year
y=temp_change_rate
plt.plot (x,y, label='Change in Temperature', color='#1a0000')
plt.title ("\nChange In Global Surface Temperature\n", color='k')
plt.xlabel ("\nYear\n", color= 'k')
plt.ylabel ("\nChange in Temperature\n", color= 'k')
plt.legend ()
plt.grid (True, color='gray')
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
data=pd.read_csv('../input/ozone-depleting-substance-emissions/ozone-depleting-substance-emissions.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#              Entity  Code  Year  \
# 27  Total emissions   NaN  1988
# 15  Total emissions   NaN  1976
# 35  Total emissions   NaN  1996
# 38  Total emissions   NaN  1999
# 46  Total emissions   NaN  2007
# 12  Total emissions   NaN  1973
# 0   Total emissions   NaN  1961
# 5   Total emissions   NaN  1966
# 7   Total emissions   NaN  1968
# 39  Total emissions   NaN  2000
#
#     Ozone-depleting substance emissions (Scientific Assessment 2014) (tonnes CFC11-equivalents)
# 27                                            1460000
# 15                                            1050000
# 35                                             700000
# 38                                             590000
# 46                                             410000
# 12                                             910000
# 0                                              380000
# 5                                              540000
# 7                                              630000
# 39                                             560000

# %%
year = df ['Year']
emission = df ['Ozone-depleting substance emissions (Scientific Assessment 2014) (tonnes CFC11-equivalents)']

# %%
x=year
y=emission
plt.plot (x,y, label='Ozone-Depleting Substance Emission', color='#008B8B')
plt.title ("\nTotal Ozone-Depleting Substance Emission over the years\n", color='k')
plt.xlabel ("\nYear\n", color= 'k')
plt.ylabel ("\nOzone-Depleting Substance Emissions (tonnes CFC11-equivalents)\n", color= 'k')
plt.legend ()
plt.grid (True, color='grey')
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
data=pd.read_csv('../input/carbon-dioxide-emission-rates/Carbon Dioxide Emission.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#      Year  Serial  Decimal_Date  Average  Interpolated   Trend  #Days
# 472  1997       7      1997.542   364.31        364.31  363.60     24
# 695  2016       2      2016.125   404.12        404.12  403.30     25
# 587  2007       2      2007.125   383.90        383.90  383.01     21
# 183  1973       6      1973.458   332.07        332.07  329.94     -1
# 184  1973       7      1973.542   330.87        330.87  330.05     -1
# 207  1975       6      1975.458   333.45        333.45  331.20     26
# 47   1962       2      1962.125   318.56        318.56  318.11     -1
# 131  1969       2      1969.125   324.42        324.42  323.89     -1
# 727  2018      10      2018.792   406.00        406.00  409.42     30
# 481  1998       4      1998.292   368.66        368.66  366.03     29

# %%
year = df ['Decimal_Date'].tail(400)
avg = df ['Average'].tail(400)

# %%
x=year
y=avg
plt.plot (x,y, label='CO2 Emission Rate', color='#8A3324')
plt.title ("\nCO2 Emission Rates over the years\n", color='k')
plt.xlabel ("\nYear\n", color= 'k')
plt.ylabel ("\nCO2 Emission  (PPM)\n", color= 'k')
plt.legend ()
plt.grid (True, color='grey')
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
data=pd.read_csv('../input/antarctic-ozone-hole-area/antarctic-ozone-hole-area.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#    Entity      Code  Year  Maximum ozone hole area (square kilometres)  \
# 17  World  OWID_WRL  1997                                     25100000
# 35  World  OWID_WRL  2015                                     28200000
# 11  World  OWID_WRL  1990                                     21100000
# 10  World  OWID_WRL  1989                                     21700000
# 5   World  OWID_WRL  1984                                     14700000
# 7   World  OWID_WRL  1986                                     14400000
# 30  World  OWID_WRL  2010                                     22600000
# 18  World  OWID_WRL  1998                                     27900000
# 23  World  OWID_WRL  2003                                     28400000
# 12  World  OWID_WRL  1991                                     22600000
#
#     Mean ozone hole area (square kilometres)
# 17                                  22100000
# 35                                  25600000
# 11                                  19200000
# 10                                  18700000
# 5                                   10100000
# 7                                   11300000
# 30                                  19400000
# 18                                  25900000
# 23                                  25800000
# 12                                  18800000

# %%
year = df ['Year']
max = df ['Maximum ozone hole area (square kilometres)']
mean = df ['Mean ozone hole area (square kilometres)']

# %%
plt.plot (year,max, label='Max', color='r')
plt.plot (year,mean, label='Mean', color='b')
plt.title ("\nAntarctic Ozone Hole Area\n", color='k')
plt.xlabel ("\nYear\n", color= 'k')
plt.ylabel ("\nOzone Hole Area (Square Kilometres)\n", color= 'k')
plt.legend ()
plt.grid (True, color='grey')
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
data=pd.read_csv('../input/dhaka-temperature/Dhaka Temperature.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#       Date Country   City       Specie  count   min   max  median  variance
# 104  05.27      BD  Dhaka  temperature     24  23.0  30.0    26.0     38.97
# 25   02.28      BD  Dhaka  temperature     20  18.0  30.0    24.0    156.29
# 12   05.16      BD  Dhaka  temperature     24  24.0  35.0    30.0    154.57
# 62   04.01      BD  Dhaka  temperature     24  24.0  37.0    28.5    220.54
# 70   04.12      BD  Dhaka  temperature     24  22.0  31.0    25.5     94.49
# 30   03.02      BD  Dhaka  temperature     24  20.0  31.0    25.0    158.68
# 120  03.01      BD  Dhaka  temperature     24  18.0  31.5    25.0    177.82
# 22   03.07      BD  Dhaka  temperature     24  21.0  28.5    22.5     41.50
# 11   05.11      BD  Dhaka  temperature     23  25.0  33.0    28.0     75.98
# 46   01.24      BD  Dhaka  temperature     24  14.0  25.0    17.5    133.44

# %%
df.set_index('Date')
df = df.sort_values(by ='Date' )
df.tail (10)
# Out:
#       Date Country   City       Specie  count   min   max  median  variance
# 85   05.18      BD  Dhaka  temperature     24  27.0  34.0    29.5     63.37
# 86   05.19      BD  Dhaka  temperature     11  28.0  32.0    28.5     16.73
# 91   05.23      BD  Dhaka  temperature     23  28.0  32.0    29.5     23.16
# 9    05.24      BD  Dhaka  temperature     24  27.0  33.0    29.0     40.71
# 87   05.25      BD  Dhaka  temperature     24  28.0  33.0    29.0     28.69
# 54   05.26      BD  Dhaka  temperature     24  27.0  33.0    29.0     39.02
# 104  05.27      BD  Dhaka  temperature     24  23.0  30.0    26.0     38.97
# 3    05.28      BD  Dhaka  temperature     24  24.0  31.0    28.5     56.07
# 82   05.29      BD  Dhaka  temperature     24  26.0  34.0    27.0     72.10
# 128  05.30      BD  Dhaka  temperature     24  25.0  32.0    27.5     49.52

# %%
date = df ['Date'].tail(61)
min = df ['min'].tail(61)
max = df ['max'].tail(61)
y_pos = np.arange(len(date))

# %%
plt.bar(y_pos, min, align='center', color='#E0115F', alpha=.80),
plt.bar(y_pos, max, align='center', color='#002147',alpha=0.75),
plt.xticks(y_pos)
plt.ylabel('\n Temperature (in Celcius)\n')
plt.title('\n Daily Temperatures in Dhaka During March & April (2020) Days\n')
plt.grid (True, color='grey')
leg=['Min', 'Max']
plt.legend(leg)
plt.rcParams['figure.figsize'] = [25, 10]
plt.show()
